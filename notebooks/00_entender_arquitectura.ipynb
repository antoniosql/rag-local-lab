# %% [markdown]
# # 00 · Entender la arquitectura del taller
#
# Este notebook no construye nada todavía.
# Su objetivo es que entiendas **qué piezas forman la solución** y cómo se conectan.
# En este workshop, la infraestructura vive en Docker y la solución Python corre en local con notebooks.
#
# ## Objetivo del laboratorio
# Al terminar deberías poder explicar:
# - qué hace Ollama,
# - qué hace Qdrant,
# - qué papel juega AnythingLLM al inicio del seminario,
# - qué hace el pipeline,
# - qué diferencia hay entre embeddings y generación,
# - por qué retrieval y generation son pasos distintos.

# %% [markdown]
# ## Mapa del sistema
#
# ```text
# AnythingLLM -> visión de producto y demo visual
#
# Documentos -> chunking -> embeddings -> Qdrant
#                                   ^
#                                   |
#                         pregunta -> embedding de la pregunta
#                                   |
#                                   v
#                              retrieval top-k
#                                   |
#                                   v
#                            prompt con contexto
#                                   |
#                                   v
#                                llama3
# ```

# %% [markdown]
# ## Ejercicio 1
#
# Escribe con tus palabras qué hace cada componente:
# - Ollama
# - modelo generativo (`llama3`)
# - modelo de embeddings (`embeddinggemma`)
# - Qdrant
# - AnythingLLM
# - pipeline

# %%
# TODO: Sustituye los textos por tus respuestas.
componentes = {
    "ollama": "",
    "modelo_generativo": "",
    "modelo_embeddings": "",
    "qdrant": "",
    "anythingllm": "",
    "pipeline": "",
}

componentes

# %% [markdown]
# ## Ejercicio 2
#
# Relaciona cada tarea con la pieza adecuada.
#
# Tareas:
# 1. Convertir una pregunta en vector.
# 2. Guardar fragmentos y metadatos.
# 3. Redactar la respuesta final.
# 4. Trocear un documento largo.
# 5. Recuperar los fragmentos más parecidos.

# %%
# TODO: Rellena el diccionario con el nombre de la pieza correcta.
tareas = {
    1: "",
    2: "",
    3: "",
    4: "",
    5: "",
}

tareas

# %% [markdown]
# ## Criterio de cierre
#
# No pases al siguiente notebook hasta que puedas explicar:
# > “Qué entra, qué sale y qué responsabilidad tiene cada capa”.
